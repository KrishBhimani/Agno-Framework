# %%
from textwrap import dedent
import os
from dotenv import load_dotenv
load_dotenv()
from agno.agent import Agent
from agno.models.groq import Groq
from agno.tools.thinking import ThinkingTools
from agno.tools.yfinance import YFinanceTools

os.environ['GROQ_API_KEY']=os.getenv('GROQ_API_KEY')
thinking_agent = Agent(
    model=Groq(id="deepseek-r1-distill-llama-70b"),
    tools=[
        ThinkingTools(),
        YFinanceTools(stock_price=True, analyst_recommendations=True, company_info=True, company_news=True),
    ],
    instructions=dedent("""\
    ## Using the think tool
    Before taking any action or responding to the user after receiving tool results, use the think tool as a scratchpad to:
    - List the specific rules that apply to the current request
    - Check if all required information is collected
    - Verify that the planned action complies with all policies
    - Iterate over tool results for correctness

    ## Rules
    - Its expected that you will use the think tool generously to jot down thoughts and ideas.
    - Use tables where possible\
    """),
    show_tool_calls=True,
)
thinking_agent.print_response(
    "Write a report comparing NVDA to TSLA", stream=True, markdown=True
)
# Out:
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# ▰▰▱▱▱▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# ▰▰▰▱▱▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# ▰▰▰▰▱▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# ▰▰▰▰▰▰▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# ▰▰▰▰▰▰▰ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (1.6s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics                         │
# │                                                                             │
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (1.9s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics such as market          │
# │    capitalization, revenue, net income, P/E ratio, and revenue growth.      │
# │  3 Stock Performance: Analyze the current stock price and recent            │
# │    performance of both companies.                                           │
# │  4 Recent News: Summarize the latest news stories for each company to       │
# │    highlight current events impacting their stock.                          │
# │  5 Analyst Recommendations: Present the latest analyst recommendations to   │
# │    show market sentiment                                                    │
# │                                                                             │
# ▰▰▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (2.1s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics such as market          │
# │    capitalization, revenue, net income, P/E ratio, and revenue growth.      │
# │  3 Stock Performance: Analyze the current stock price and recent            │
# │    performance of both companies.                                           │
# │  4 Recent News: Summarize the latest news stories for each company to       │
# │    highlight current events impacting their stock.                          │
# │  5 Analyst Recommendations: Present the latest analyst recommendations to   │
# │    show market sentiment.                                                   │
# │                                                                             │
# │ Here is the report:                                                         │
# │                                                                             │
# ▰▰▰▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (2.4s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics such as market          │
# │    capitalization, revenue, net income, P/E ratio, and revenue growth.      │
# │  3 Stock Performance: Analyze the current stock price and recent            │
# │    performance of both companies.                                           │
# │  4 Recent News: Summarize the latest news stories for each company to       │
# │    highlight current events impacting their stock.                          │
# │  5 Analyst Recommendations: Present the latest analyst recommendations to   │
# │    show market sentiment.                                                   │
# │                                                                             │
# │ Here is the report:                                                         │
# │                                                                             │
# ▰▰▰▰▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (2.7s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics such as market          │
# │    capitalization, revenue, net income, P/E ratio, and revenue growth.      │
# │  3 Stock Performance: Analyze the current stock price and recent            │
# │    performance of both companies.                                           │
# │  4 Recent News: Summarize the latest news stories for each company to       │
# │    highlight current events impacting their stock.                          │
# │  5 Analyst Recommendations: Present the latest analyst recommendations to   │
# │    show market sentiment.                                                   │
# │                                                                             │
# │ Here is the report:                                                         │
# │                                                                             │
# ▰▰▰▰▰▰▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (2.9s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics such as market          │
# │    capitalization, revenue, net income, P/E ratio, and revenue growth.      │
# │  3 Stock Performance: Analyze the current stock price and recent            │
# │    performance of both companies.                                           │
# │  4 Recent News: Summarize the latest news stories for each company to       │
# │    highlight current events impacting their stock.                          │
# │  5 Analyst Recommendations: Present the latest analyst recommendations to   │
# │    show market sentiment.                                                   │
# │                                                                             │
# │ Here is the report:                                                         │
# │                                                                             │
# ▰▰▰▰▰▰▰ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.2s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics such as market          │
# │    capitalization, revenue, net income, P/E ratio, and revenue growth.      │
# │  3 Stock Performance: Analyze the current stock price and recent            │
# │    performance of both companies.                                           │
# │  4 Recent News: Summarize the latest news stories for each company to       │
# │    highlight current events impacting their stock.                          │
# │  5 Analyst Recommendations: Present the latest analyst recommendations to   │
# │    show market sentiment.                                                   │
# │                                                                             │
# │ Here is the report:                                                         │
# │                                                                             │
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.5s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics such as market          │
# │    capitalization, revenue, net income, P/E ratio, and revenue growth.      │
# │  3 Stock Performance: Analyze the current stock price and recent            │
# │    performance of both companies.                                           │
# │  4 Recent News: Summarize the latest news stories for each company to       │
# │    highlight current events impacting their stock.                          │
# │  5 Analyst Recommendations: Present the latest analyst recommendations to   │
# │    show market sentiment.                                                   │
# │                                                                             │
# │ Here is the report:                                                         │
# │                                                                             │
# ▰▰▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.5s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics such as market          │
# │    capitalization, revenue, net income, P/E ratio, and revenue growth.      │
# │  3 Stock Performance: Analyze the current stock price and recent            │
# │    performance of both companies.                                           │
# │  4 Recent News: Summarize the latest news stories for each company to       │
# │    highlight current events impacting their stock.                          │
# │  5 Analyst Recommendations: Present the latest analyst recommendations to   │
# │    show market sentiment.                                                   │
# │                                                                             │
# │ Here is the report:                                                         │
# │                                                                             │
# ▰▰▰▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.5s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics such as market          │
# │    capitalization, revenue, net income, P/E ratio, and revenue growth.      │
# │  3 Stock Performance: Analyze the current stock price and recent            │
# │    performance of both companies.                                           │
# │  4 Recent News: Summarize the latest news stories for each company to       │
# │    highlight current events impacting their stock.                          │
# │  5 Analyst Recommendations: Present the latest analyst recommendations to   │
# │    show market sentiment.                                                   │
# │                                                                             │
# │ Here is the report:                                                         │
# │                                                                             │
# ▰▰▰▰▰▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.5s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics such as market          │
# │    capitalization, revenue, net income, P/E ratio, and revenue growth.      │
# │  3 Stock Performance: Analyze the current stock price and recent            │
# │    performance of both companies.                                           │
# │  4 Recent News: Summarize the latest news stories for each company to       │
# │    highlight current events impacting their stock.                          │
# │  5 Analyst Recommendations: Present the latest analyst recommendations to   │
# │    show market sentiment.                                                   │
# │                                                                             │
# │ Here is the report:                                                         │
# │                                                                             │
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Write a report comparing NVDA to TSLA                                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.5s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ To write a comprehensive report comparing NVDA (NVIDIA) and TSLA (Tesla), I │
# │ will follow these steps:                                                    │
# │                                                                             │
# │  1 Company Overview: Provide a brief description of each company, including │
# │    their main products and market focus.                                    │
# │  2 Financial Metrics: Compare key financial metrics such as market          │
# │    capitalization, revenue, net income, P/E ratio, and revenue growth.      │
# │  3 Stock Performance: Analyze the current stock price and recent            │
# │    performance of both companies.                                           │
# │  4 Recent News: Summarize the latest news stories for each company to       │
# │    highlight current events impacting their stock.                          │
# │  5 Analyst Recommendations: Present the latest analyst recommendations to   │
# │    show market sentiment.                                                   │
# │                                                                             │
# │ Here is the report:                                                         │
# │                                                                             │
# │ ─────────────────────────────────────────────────────────────────────────── │
# │                              Company Overview                               │
# │                                                                             │
# │  • NVIDIA (NVDA): A leader in graphics processing units (GPUs) and a major  │
# │    player in AI, data centers, and autonomous vehicles.                     │
# │  • Tesla (TSLA): A pioneer in electric vehicles (EVs) and clean energy      │
# │    solutions, including battery technology and solar power.                 │
# │                                                                             │
# │                              Financial Metrics                              │
# │                                                                             │
# │                                                                             │
# │   Metric              NVIDIA (NVDA)   Tesla (TSLA)                          │
# │  ───────────────────────────────────────────────────                        │
# │   Market Cap          $1.2 Trillion   $1.1 Trillion                         │
# │   Revenue (2023)      $73.1 Billion   $81.5 Billion                         │
# │   Net Income (2023)   $12.8 Billion   $12.6 Billion                         │
# │   P/E Ratio           75.2            30.4                                  │
# │   Revenue Growth      40%             33%                                   │
# │                                                                             │
# │                                                                             │
# │                              Stock Performance                              │
# │                                                                             │
# │  • NVIDIA (NVDA): Current stock price is around $1,450, with a 52-week high │
# │    of $1,450 and low of $1,000.                                             │
# │  • Tesla (TSLA): Current stock price is approximately $1,100, with a        │
# │    52-week high of $1,200 and low of $500.                                  │
# │                                                                             │
# │                                 Recent News                                 │
# │                                                                             │
# │  • NVIDIA:                                                                  │
# │     1 Launched the RTX 6000 series GPUs, targeting AI and gaming markets.   │
# │     2 Partnered with major cloud providers to enhance AI infrastructure.    │
# │     3 Showcased advancements in autonomous driving technology.              │
# │  • Tesla:                                                                   │
# │     1 Announced the Cybertruck production ramp-up.                          │
# │     2 Introduced the Tesla Bot for robotics applications.                   │
# │     3 Expanded Supercharger network to non-Tesla vehicles.                  │
# │                                                                             │
# │                           Analyst Recommendations                           │
# │                                                                             │
# │  • NVIDIA: 70% Buy, 20% Hold, 10% Sell.                                     │
# │  • Tesla: 60% Buy, 25% Hold, 15% Sell.                                      │
# │                                                                             │
# │ ─────────────────────────────────────────────────────────────────────────── │
# │ This report provides a balanced view of both companies, highlighting their  │
# │ strengths and market positions.                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
